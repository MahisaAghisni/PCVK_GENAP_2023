# %% [markdown]
# <a href="https://colab.research.google.com/github/MahisaAghisni/PCVK_GENAP_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/kucing.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/kucing.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,2024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
#Tampilkan plot dengan ukuran kanvas yang lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#Memberikan koordinat titik pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0), thickness = 10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255), thickness = 15)
plt.imshow(black_img)

# %%
#Menambahkan lingkaran
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0), thickness = 8)
plt.imshow(black_img)

# %%
#Menambahkan garis horizontal
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness = 5)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(400,400),radius=50,color=(255,0,0),thickness=-1)
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
#Menambahkan Text
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2 = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200], [400,300], [200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G,B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
#Menambahkan Polyline
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0), thickness = 5)
plt.imshow(black_img2)

# %% [markdown]
# Tugas

# %%
#tugas no 2
img = cv.imread('/content/drive/MyDrive/kucing.jpg')
b,g,r = cv.split(img)
img_rb = cv.merge((r,g*0,b))
plt.imshow(img_rb)

# %%
b,g,r = cv.split(img)
img_gb = cv.merge((r*0,g,b))
plt.imshow(img_gb)

# %%
img_3 = img[20:115,25:120]
plt.imshow(img_3)

# %%
plt.imshow(img[5:30], cmap='Reds')

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
plt.imshow(img5)

# %%
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(6,6))
cv.rectangle(imageWithRectangle, pt1=(75,80), pt2=(100,50), color=(0,255, 255), thickness = 2)
cv.rectangle(imageWithRectangle, pt1=(20,80), pt2=(40,100), color=(0,255,0), thickness = 2)
cv.rectangle(imageWithRectangle, pt1=(20,30), pt2=(50,60), color=(255,255,255), thickness = 2)
cv.rectangle(imageWithRectangle, pt1=(125,50), pt2=(150,70), color=(255,0,0), thickness = 2)
cv.rectangle(imageWithRectangle, pt1=(60,80), pt2=(50,100), color=(0,0,255),thickness= 2)
plt.imshow(imageWithRectangle)

# %%
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(100,50), pt2=(70,15), color=(255, 0, 30), thickness = 2)
cv.circle(img, center=(85, 30), radius=25, color=(180, 105, 255), thickness = 2)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
img = cv.imread('/content/drive/MyDrive/kucing.jpg')
img_8 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
img_8[80:,:25,0] = 0
img_8[80:,:25,1] = 0
plt.imshow(img_8)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
img_9 = img_8.copy()
cv.putText(img_8,text='Hello',org=(125,15),fontFace=font,fontScale=0.5,color=(0,0,0),thickness=1,lineType=cv.LINE_AA)
plt.imshow(img_8)
